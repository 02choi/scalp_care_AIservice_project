# %%
import os
import numpy as np

# %%
base_dir = 'D:/scalp_image_multi'

train_dir = os.path.join(base_dir,'training')
val_dir = os.path.join(base_dir,'validation')

# %%
train_bd_dir = os.path.join(train_dir,'bd')
train_hb_dir = os.path.join(train_dir,'hb')
train_tm_dir = os.path.join(train_dir,'tm')   
train_pj_dir = os.path.join(train_dir,'pj')
train_gj_dir = os.path.join(train_dir,'gj')

# %%
train_bd_fnames=os.listdir(train_bd_dir)
train_hb_fnames=os.listdir(train_hb_dir)
train_tm_fnames=os.listdir(train_tm_dir)
train_pj_fnames=os.listdir(train_pj_dir)
train_gj_fnames=os.listdir(train_gj_dir)

# %%
val_bd_dir = os.path.join(val_dir,'bd')
val_hb_dir = os.path.join(val_dir,'hb')
val_tm_dir = os.path.join(val_dir,'tm')   
val_pj_dir = os.path.join(val_dir,'pj')
val_gj_dir = os.path.join(val_dir,'gj')

# %%
val_bd_fnames=os.listdir(val_bd_dir)
val_hb_fnames=os.listdir(val_hb_dir)
val_tm_fnames=os.listdir(val_tm_dir)
val_pj_fnames=os.listdir(val_pj_dir)
val_gj_fnames=os.listdir(val_gj_dir)

# %%
same = []
for i in train_hb_fnames:
  if i in train_bd_fnames:
    same.append(i)
  if i in train_tm_fnames:
    same.append(i)
  if i in train_pj_fnames:
    same.append(i)
  if i in train_gj_fnames:
    same.append(i)

same1 = np.unique(same)
print(same1)
# Out:
# ['0131_A2LEBJJDE00166C_1604645589854_3_TH.jpg'
#  '0131_A2LEBJJDE00166C_1604905984677_4_LH.jpg'
#  '0335_A2LEBJJDE000542_1603430474350_2_TH.jpg'
#  '0335_A2LEBJJDE000542_1604364944333_5_RH.jpg'
#  '0335_A2LEBJJDE000542_1604449407695_6_BH.jpg'
#  '0335_A2LEBJJDE000542_1604725063669_5_RH.jpg'
#  '0335_A2LEBJJDE000542_1604725246868_2_TH.jpg'
#  '0335_A2LEBJJDE000542_1604725246868_3_TH.jpg'
#  '0335_A2LEBJJDE000542_1604903770289_5_RH.jpg'
#  '0335_A2LEBJJDE000542_1604976182750_4_LH.jpg'
#  '0335_A2LEBJJDE000542_1604976182750_5_RH.jpg'
#  '0335_A2LEBJJDE000542_1604976182750_6_BH.jpg'
#  '0335_A2LEBJJDE000542_1604981120969_2_TH.jpg'
#  '0335_A2LEBJJDE000542_1604981120969_3_TH.jpg'
#  '0335_A2LEBJJDE000542_1605148324310_4_LH.jpg'
#  '0335_A2LEBJJDE000542_1605157522593_2_TH.jpg'
#  '0335_A2LEBJJDE000542_1605758398669_6_BH.jpg'
#  '0556_A2LEBJJDE00041T_1602841092035_6_BH.jpg'
#  '0556_A2LEBJJDE00041T_1602841142666_5_RH.jpg'
#  '0556_A2LEBJJDE00041T_1603800089607_4_LH.jpg'
# ...

# %%
for i in same1:
    dir = train_hb_dir +'/'+ i
    os.remove(dir)

# %%
train_hb_fnames=os.listdir(train_hb_dir)

# %%
len(train_hb_fnames)
# Out:
# 3805

# %%
same = []
for i in train_pj_fnames:
  if i in train_hb_fnames:
    same.append(i)
  if i in train_tm_fnames:
    same.append(i)
  if i in train_bd_fnames:
    same.append(i)
  if i in train_gj_fnames:
    same.append(i)

same1 = np.unique(same)
print(same1)
# Out:
# ['0335_A2LEBJJDE000542_1603852555231_4_LH.jpg'
#  '0335_A2LEBJJDE000542_1604725246868_2_TH.jpg'
#  '0556_A2LEBJJDE00041T_1602840991236_5_RH.jpg'
#  '0616_A2LEBJJDE00004W_1603266700774_6_BH.jpg'
#  '0617_A2LEBJJDE000815_1606214102654_3_TH.jpg'
#  '0663_A2LEBJJDE001716_1605336092696_4_LH.jpg'
#  '0663_A2LEBJJDE001716_1605336092696_5_RH.jpg'
#  '0663_A2LEBJJDE001716_1605673344949_6_BH.jpg'
#  '0663_A2LEBJJDE001716_1605851725333_2_TH.jpg'
#  '0663_A2LEBJJDE001716_1606269662249_2_TH.jpg'
#  '0703_A2LEBJJDE000774_1605503435781_6_BH.jpg'
#  '0715_A2LEBJJDE00175D_1605486504920_6_BH.jpg'
#  '0715_A2LEBJJDE00175D_1605490270965_2_TH.jpg'
#  '0844_A2LEBJJDE00067A_1602914264139_5_RH.jpg'
#  '0844_A2LEBJJDE00067A_1602914331489_2_TH.jpg'
#  '0844_A2LEBJJDE00067A_1605858102866_3_TH.jpg'
#  '1015_A2LEBJJDE000592_1602824631228_3_TH.jpg'
#  '1015_A2LEBJJDE000592_1603097754050_3_TH.jpg'
#  '1069_A2LEBJJDE00094D_1605172758919_2_TH.jpg'
#  '1069_A2LEBJJDE00094D_1605172758919_3_TH.jpg'
# ...

# %%
for i in same1:
    dir = train_pj_dir +'/'+ i
    os.remove(dir)

# %%
train_pj_fnames=os.listdir(train_pj_dir)

# %%
len(train_pj_fnames)
# Out:
# 3430

# %%
same = []
for i in train_bd_fnames:
  if i in train_hb_fnames:
    same.append(i)
  if i in train_pj_fnames:
    same.append(i)
  if i in train_tm_fnames:
    same.append(i)
  if i in train_gj_fnames:
    same.append(i)
    
same1 = np.unique(same)
print(same1)
# Out:
# ['0335_A2LEBJJDE000542_1604364944333_5_RH.jpg'
#  '0556_A2LEBJJDE00041T_1602844959183_6_BH.jpg'
#  '0616_A2LEBJJDE00004W_1605868185330_5_RH.jpg'
#  '0733_A2LEBJJDE000084_1603260271876_2_TH.jpg'
#  '0770_A2LEBJJDE000865_1602897710491_5_RH.jpg'
#  '0770_A2LEBJJDE000865_1604139267230_2_TH.jpg'
#  '1071_A2LEBJJDE00173R_1605269538725_6_BH.jpg'
#  '1071_A2LEBJJDE00173R_1606092467304_6_BH.jpg'
#  '1080_A2LEBJJDE00092R_1603788793474_4_LH.jpg'
#  '1080_A2LEBJJDE00092R_1603792101344_4_LH.jpg'
#  '1080_A2LEBJJDE00092R_1603792101344_5_RH.jpg'
#  '1142_A2LEBJJDE00024K_1605418822426_2_TH.jpg'
#  '1145_A2LEBJJDE00119L_1604798592978_6_BH.jpg'
#  '1145_A2LEBJJDE00119L_1606026287710_5_RH.jpg'
#  '1195_A2LEBJJDE00117Z_1603440576906_4_LH.jpg'
#  '1459_A2LEBJJDE00025D_1603269742090_5_RH.jpg'
#  '1459_A2LEBJJDE00025D_1605073096279_5_RH.jpg'
#  '1631_A2LEBJJDE00163X_1605693250370_4_LH.jpg'
#  '1719_A2LEBJJDE00138G_1603786767702_6_BH.jpg'
#  '1719_A2LEBJJDE00138G_1603850831628_4_LH.jpg'
# ...

# %%
for i in same1:
    dir = train_bd_dir +'/'+ i
    os.remove(dir)

# %%
train_bd_fnames=os.listdir(train_bd_dir)

# %%
len(train_bd_fnames)
# Out:
# 2047

# %%
same = []
for i in train_gj_fnames:
  if i in train_hb_fnames:
    same.append(i)
  if i in train_pj_fnames:
    same.append(i)
  if i in train_tm_fnames:
    same.append(i)
  if i in train_bd_fnames:
    same.append(i)
    
same1 = np.unique(same)
print(same1)
# Out:
# ['0888_A2LEBJJDE001948_1604116252212_5_RH.jpg'
#  '1719_A2LEBJJDE00138G_1602834858585_4_LH.jpg'
#  '1719_A2LEBJJDE00138G_1604134680288_5_RH.jpg'
#  '1981_A2LEBJJDE001901_1605233671688_4_LH.jpg'
#  '2585_A2LEBJJDE001302_1602833549493_5_RH.jpg'
#  '2585_A2LEBJJDE001302_1603344954587_5_RH.jpg'
#  '2585_A2LEBJJDE001302_1604723237813_5_RH.jpg'
#  '2959_A2LEBJJDE00097R_1604125654519_2_TH.jpg'
#  '3365_A2LEBJJDE00106D_1604712290951_3_TH.jpg'
#  '3588_A2LEBJJDE00108Y_1604118948397_5_RH.jpg'
#  '3588_A2LEBJJDE00108Y_1604643070099_3_TH.jpg'
#  '3654_A2LEBJJDE00016C_1602470053359_3_TH.jpg'
#  '5569_A2LEBJJDE001211_1604107495694_6_BH.jpg'
#  '7027_A2LEBJJDE001117_1606013912709_5_RH.jpg'
#  '7126_A2LEBJJDE001534_1606296684512_5_RH.jpg'
#  '8146_A2LEBJJDE00148A_1604479316809_2_TH.jpg']

# %%
for i in same1:
    dir = train_gj_dir +'/'+ i
    os.remove(dir)

# %%
train_gj_fnames=os.listdir(train_gj_dir)

# %%
len(train_gj_fnames)
# Out:
# 2222

# %%
same = []
for i in val_hb_fnames:
  if i in val_bd_fnames:
    same.append(i)
  if i in val_tm_fnames:
    same.append(i)
  if i in val_pj_fnames:
    same.append(i)
  if i in val_gj_fnames:
    same.append(i)

same1 = np.unique(same)
print(same1)
# Out:
# ['0013_A2LEBJJDE00060O_1606386172558_6_BH.jpg'
#  '0013_A2LEBJJDE00060O_1606550973883_5_RH.jpg'
#  '0013_A2LEBJJDE00060O_1606551038976_5_RH.jpg'
#  '0013_A2LEBJJDE00060O_1606706953049_2_TH.jpg'
#  '0425_A2LEBJJDE00079P_1606551499327_6_BH.jpg'
#  '0425_A2LEBJJDE00079P_1606740874489_2_TH.jpg'
#  '0616_A2LEBJJDE00004W_1606714826448_3_TH.jpg'
#  '0616_A2LEBJJDE00004W_1606716009120_6_BH.jpg'
#  '0663_A2LEBJJDE001716_1606370189672_2_TH.jpg'
#  '0715_A2LEBJJDE00175D_1606707136912_4_LH.jpg'
#  '0715_A2LEBJJDE00175D_1606883979785_5_RH.jpg'
#  '0715_A2LEBJJDE00175D_1607495151596_3_TH.jpg'
#  '0715_A2LEBJJDE00175D_1607495207485_3_TH.jpg'
#  '0715_A2LEBJJDE00175D_1608812119681_3_TH.jpg'
#  '0715_A2LEBJJDE00175D_1608812150048_3_TH.jpg'
#  '0770_A2LEBJJDE000865_1606904927324_5_RH.jpg'
#  '1069_A2LEBJJDE00094D_1606635170363_5_RH.jpg'
#  '1069_A2LEBJJDE00094D_1607144873059_4_LH.jpg'
#  '1080_A2LEBJJDE00092R_1607044953509_6_BH.jpg'
#  '1221_A1LCAIHDH00009X_1609127442914_2_TH.jpg'
# ...

# %%
for i in same1:
    dir = val_hb_dir +'/'+ i
    os.remove(dir)

# %%
val_hb_fnames=os.listdir(val_hb_dir)

# %%
len(val_hb_fnames)
# Out:
# 1136

# %%
same = []
for i in val_pj_fnames:
  if i in val_bd_fnames:
    same.append(i)
  if i in val_tm_fnames:
    same.append(i)
  if i in val_hb_fnames:
    same.append(i)
  if i in val_gj_fnames:
    same.append(i)

same1 = np.unique(same)
print(same1)
# Out:
# ['0425_A2LEBJJDE00079P_1606739115095_4_LH.jpg'
#  '0425_A2LEBJJDE00079P_1606739252195_4_LH.jpg'
#  '0643_A2LEBJJDE00048F_1606721730853_3_TH.jpg'
#  '0715_A2LEBJJDE00175D_1606707136912_4_LH.jpg'
#  '0715_A2LEBJJDE00175D_1606707136912_6_BH.jpg'
#  '1719_A2LEBJJDE00138G_1607406523548_2_TH.jpg'
#  '2327_A2LEBJJDE00091Y_1608432057398_4_LH.jpg'
#  '2585_A2LEBJJDE001302_1607058026257_2_TH.jpg'
#  '2720_A2LEBJJDE000401_1607052744454_5_RH.jpg'
#  '2800_A2LEBJJDE00036Z_1606541290239_3_TH.jpg'
#  '3006_A1LCAIHDH00007C_1608265904789_6_BH.jpg'
#  '3269_A2LEBJJDE00096Y_1608089637317_2_TH.jpg'
#  '3269_A2LEBJJDE00096Y_1608089637317_3_TH.jpg'
#  '3858_A2LEBJJDE00076B_1607867092524_5_RH.jpg'
#  '3977_A2LCBJCAC000073_1607311034342_2_TH.jpg'
#  '3977_A2LCBJCAC000073_1607311378227_3_TH.jpg'
#  '3977_A2LCBJCAC000073_1607311504190_2_TH.jpg'
#  '3977_A2LCBJCAC000073_1607311565499_2_TH.jpg'
#  '3977_A2LCBJCAC000073_1607325623499_3_TH.jpg'
#  '3977_A2LCBJCAC000073_1607325842114_2_TH.jpg'
# ...

# %%
for i in same1:
    dir = val_pj_dir +'/'+ i
    os.remove(dir)

# %%
val_pj_fnames=os.listdir(val_pj_dir)

# %%
len(val_pj_fnames)
# Out:
# 1026

# %%
same = []
for i in val_bd_fnames:
  if i in val_pj_fnames:
    same.append(i)
  if i in val_tm_fnames:
    same.append(i)
  if i in val_hb_fnames:
    same.append(i)
  if i in val_gj_fnames:
    same.append(i)

same1 = np.unique(same)
print(same1)
# Out:
# ['0715_A2LEBJJDE00175D_1606883979785_6_BH.jpg'
#  '0715_A2LEBJJDE00175D_1608812347291_5_RH.jpg'
#  '0715_A2LEBJJDE00175D_1608812347291_6_BH.jpg'
#  '0888_A2LEBJJDE001948_1608948077102_2_TH.jpg'
#  '1069_A2LEBJJDE00094D_1607579389669_6_BH.jpg'
#  '1221_A1LCAIHDH00009X_1608189529557_4_LH.jpg'
#  '1221_A1LCAIHDH00009X_1608364272281_6_BH.jpg'
#  '1963_A2LCBJCAC00003V_1609129435875_6_BH.jpg'
#  '2479_A2LEBJJDE00147H_1607649866541_2_TH.jpg'
#  '3006_A1LCAIHDH00007C_1607652274714_6_BH.jpg'
#  '3006_A1LCAIHDH00007C_1607759976325_5_RH.jpg'
#  '3006_A1LCAIHDH00007C_1608201488607_4_LH.jpg'
#  '3006_A1LCAIHDH00007C_1608346711361_3_TH.jpg'
#  '3006_A1LCAIHDH00007C_1608367169629_6_BH.jpg'
#  '3216_A1LCAIHDH00006J_1607661168715_6_BH.jpg'
#  '3216_A1LCAIHDH00006J_1608861197502_2_TH.jpg'
#  '3216_A1LCAIHDH00006J_1609226046223_3_TH.jpg'
#  '3263_A1LCAIHDH00014R_1607734004742_6_BH.jpg'
#  '3263_A1LCAIHDH00014R_1607758695744_6_BH.jpg'
#  '3263_A1LCAIHDH00014R_1608777751162_6_BH.jpg'
# ...

# %%
for i in same1:
    dir = val_bd_dir +'/'+ i
    os.remove(dir)

# %%
val_bd_fnames=os.listdir(val_bd_dir)

# %%
len(val_bd_fnames)
# Out:
# 584

# %%
same = []
for i in val_gj_fnames:
  if i in val_pj_fnames:
    same.append(i)
  if i in val_tm_fnames:
    same.append(i)
  if i in val_hb_fnames:
    same.append(i)
  if i in val_bd_fnames:
    same.append(i)

same1 = np.unique(same)
print(same1)
# Out:
# ['4015_A2LEBJJDE00150P_1606702995620_5_RH.jpg'
#  '4162_A2LEBJJDE00013X_1607649398445_5_RH.jpg'
#  '4162_A2LEBJJDE00013X_1607652989908_4_LH.jpg']

# %%
for i in same1:
    dir = val_gj_dir +'/'+ i
    os.remove(dir)

# %%
val_gj_fnames=os.listdir(val_gj_dir)

# %%
len(val_gj_fnames)
# Out:
# 649
